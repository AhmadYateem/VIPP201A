# %%
import numpy as np
import glob
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers

# %%
cpp_images = []
cpp_labels = []
for i in range(1, 201):
    img_path = "/content/CPP" + '/cpp_example' + str(i) + ".png"
    img = load_img(img_path, target_size=(128, 128))
    img_array = img_to_array(img) / 255.0
    cpp_images.append(img_array)
    cpp_labels.append(0)

# %%
python_images = []
python_labels = []
for i in range(1, 201):
    img_path = "/content/Python" + '/python_example' + str(i) + ".png"
    img = load_img(img_path, target_size=(128, 128))
    img_array = img_to_array(img) / 255.0
    python_images.append(img_array)
    python_labels.append(1)

# %%
images = np.array(cpp_images + python_images)
labels = np.array(cpp_labels + python_labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# %%
model = keras.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(2, activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), batch_size=32)

test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 4.5548e-05 - val_accuracy: 1.0000 - val_loss: 6.6376e-05
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 3.9490e-05 - val_accuracy: 1.0000 - val_loss: 5.2461e-05
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 2.2818e-05 - val_accuracy: 1.0000 - val_loss: 4.6560e-05
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.0025e-05 - val_accuracy: 1.0000 - val_loss: 3.7999e-05
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.6735e-05 - val_accuracy: 1.0000 - val_loss: 2.9428e-05
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.4612e-05 - val_accuracy: 1.0000 - val_loss: 2.7916e-05
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.3220e-05 - val_accuracy: 1.0000 - val_loss: 2.3229e-05
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.1628e-05 - val_accuracy: 1.0000 - val_loss: 1.9037e-05
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 7.4927e-06 - val_accuracy: 1.0000 - val_loss: 1.8192e-05
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 6.4724e-06 - val_accuracy: 1.0000 - val_loss: 1.4759e-05
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 5.4766e-06 - val_accuracy: 1.0000 - val_loss: 1.2998e-05
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 4.7206e-06 - val_accuracy: 1.0000 - val_loss: 1.2275e-05
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 5.5186e-06 - val_accuracy: 1.0000 - val_loss: 1.1033e-05
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 4.6009e-06 - val_accuracy: 1.0000 - val_loss: 1.0172e-05
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 3.2430e-06 - val_accuracy: 1.0000 - val_loss: 9.8440e-06
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.9272e-06 - val_accuracy: 1.0000 - val_loss: 8.6761e-06
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 3.5491e-06 - val_accuracy: 1.0000 - val_loss: 7.6332e-06
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.6380e-06 - val_accuracy: 1.0000 - val_loss: 7.2533e-06
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.3114e-06 - val_accuracy: 1.0000 - val_loss: 6.8346e-06
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.1433e-06 - val_accuracy: 1.0000 - val_loss: 6.7616e-06
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.9621e-06 - val_accuracy: 1.0000 - val_loss: 6.0256e-06
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.4891e-06 - val_accuracy: 1.0000 - val_loss: 5.4773e-06
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.1055e-06 - val_accuracy: 1.0000 - val_loss: 5.2508e-06
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.7667e-06 - val_accuracy: 1.0000 - val_loss: 5.0646e-06
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.8097e-06 - val_accuracy: 1.0000 - val_loss: 4.7845e-06
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.4153e-06 - val_accuracy: 1.0000 - val_loss: 4.7248e-06
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.5145e-06 - val_accuracy: 1.0000 - val_loss: 4.2183e-06
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.4844e-06 - val_accuracy: 1.0000 - val_loss: 4.1304e-06
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 1.3283e-06 - val_accuracy: 1.0000 - val_loss: 3.9069e-06
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.1571e-06 - val_accuracy: 1.0000 - val_loss: 3.6834e-06
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.2196e-06 - val_accuracy: 1.0000 - val_loss: 3.5329e-06
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0206e-06 - val_accuracy: 1.0000 - val_loss: 3.4271e-06
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.0157e-06 - val_accuracy: 1.0000 - val_loss: 3.1425e-06
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 9.5258e-07 - val_accuracy: 1.0000 - val_loss: 3.0889e-06
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 8.9855e-07 - val_accuracy: 1.0000 - val_loss: 3.0620e-06
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 8.7845e-07 - val_accuracy: 1.0000 - val_loss: 2.8669e-06
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 7.4023e-07 - val_accuracy: 1.0000 - val_loss: 2.8207e-06
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 6.4473e-07 - val_accuracy: 1.0000 - val_loss: 2.6568e-06
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 7.7886e-07 - val_accuracy: 1.0000 - val_loss: 2.5033e-06
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 7.3566e-07 - val_accuracy: 1.0000 - val_loss: 2.3558e-06
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 6.2732e-07 - val_accuracy: 1.0000 - val_loss: 2.3319e-06
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 5.7510e-07 - val_accuracy: 1.0000 - val_loss: 2.2738e-06
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 5.3599e-07 - val_accuracy: 1.0000 - val_loss: 2.1934e-06
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 5.5061e-07 - val_accuracy: 1.0000 - val_loss: 2.0220e-06
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 5.3185e-07 - val_accuracy: 1.0000 - val_loss: 1.9550e-06
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 5.5121e-07 - val_accuracy: 1.0000 - val_loss: 1.7762e-06
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 3.7505e-07 - val_accuracy: 1.0000 - val_loss: 1.8566e-06
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 4.4266e-07 - val_accuracy: 1.0000 - val_loss: 1.6331e-06
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 3.6458e-07 - val_accuracy: 1.0000 - val_loss: 1.6063e-06
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 3.6684e-07 - val_accuracy: 1.0000 - val_loss: 1.5512e-06
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 3.7994e-07 - val_accuracy: 1.0000 - val_loss: 1.3351e-06
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.8364e-07 - val_accuracy: 1.0000 - val_loss: 1.3545e-06
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.8894e-07 - val_accuracy: 1.0000 - val_loss: 1.2904e-06
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.5516e-07 - val_accuracy: 1.0000 - val_loss: 1.1697e-06
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 3.0377e-07 - val_accuracy: 1.0000 - val_loss: 9.9240e-07
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.6887e-07 - val_accuracy: 1.0000 - val_loss: 1.1086e-06
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 2.1596e-07 - val_accuracy: 1.0000 - val_loss: 8.7320e-07
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 2.4323e-07 - val_accuracy: 1.0000 - val_loss: 8.3147e-07
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.7877e-07 - val_accuracy: 1.0000 - val_loss: 8.0763e-07
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.7490e-07 - val_accuracy: 1.0000 - val_loss: 7.3462e-07
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 1.8143e-07 - val_accuracy: 1.0000 - val_loss: 7.1823e-07
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.9132e-07 - val_accuracy: 1.0000 - val_loss: 6.7650e-07
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 1.2370e-07 - val_accuracy: 1.0000 - val_loss: 5.8412e-07
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 1.5347e-07 - val_accuracy: 1.0000 - val_loss: 6.0200e-07
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.5805e-07 - val_accuracy: 1.0000 - val_loss: 5.4687e-07
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.2691e-07 - val_accuracy: 1.0000 - val_loss: 4.9471e-07
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 1.2860e-07 - val_accuracy: 1.0000 - val_loss: 4.9322e-07
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 8.6255e-08 - val_accuracy: 1.0000 - val_loss: 4.3064e-07
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 8.1228e-08 - val_accuracy: 1.0000 - val_loss: 4.1723e-07
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 7.5717e-08 - val_accuracy: 1.0000 - val_loss: 3.9041e-07
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 7.5114e-08 - val_accuracy: 1.0000 - val_loss: 3.7849e-07
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 7.4785e-08 - val_accuracy: 1.0000 - val_loss: 3.4570e-07
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 6.3305e-08 - val_accuracy: 1.0000 - val_loss: 3.1590e-07
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 6.3058e-08 - val_accuracy: 1.0000 - val_loss: 3.2335e-07
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 5.3573e-08 - val_accuracy: 1.0000 - val_loss: 2.8908e-07
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 5.5164e-08 - val_accuracy: 1.0000 - val_loss: 2.8759e-07
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 4.6561e-08 - val_accuracy: 1.0000 - val_loss: 2.7716e-07
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 5.3459e-08 - val_accuracy: 1.0000 - val_loss: 2.5630e-07
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 4.5384e-08 - val_accuracy: 1.0000 - val_loss: 2.5034e-07
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 3.8815e-08 - val_accuracy: 1.0000 - val_loss: 2.5183e-07
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 4.7875e-08 - val_accuracy: 1.0000 - val_loss: 2.1160e-07
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 3.5914e-08 - val_accuracy: 1.0000 - val_loss: 2.2352e-07
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 3.6507e-08 - val_accuracy: 1.0000 - val_loss: 1.9520e-07
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 3.4094e-08 - val_accuracy: 1.0000 - val_loss: 2.0265e-07
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.7140e-08 - val_accuracy: 1.0000 - val_loss: 1.8477e-07
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 2.5159e-08 - val_accuracy: 1.0000 - val_loss: 1.8030e-07
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.7517e-08 - val_accuracy: 1.0000 - val_loss: 1.7285e-07
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.5353e-08 - val_accuracy: 1.0000 - val_loss: 1.7136e-07
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.6862e-08 - val_accuracy: 1.0000 - val_loss: 1.5348e-07
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.4308e-08 - val_accuracy: 1.0000 - val_loss: 1.6391e-07
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 3.1350e-08 - val_accuracy: 1.0000 - val_loss: 1.4901e-07
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 2.5325e-08 - val_accuracy: 1.0000 - val_loss: 1.5795e-07
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.0078e-08 - val_accuracy: 1.0000 - val_loss: 1.3411e-07
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.6087e-08 - val_accuracy: 1.0000 - val_loss: 1.4752e-07
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.4285e-08 - val_accuracy: 1.0000 - val_loss: 1.3411e-07
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.8299e-08 - val_accuracy: 1.0000 - val_loss: 1.3560e-07
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.8252e-08 - val_accuracy: 1.0000 - val_loss: 1.3113e-07
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.4288e-08 - val_accuracy: 1.0000 - val_loss: 1.2815e-07
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 1.7951e-08 - val_accuracy: 1.0000 - val_loss: 1.3113e-07
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 2.2315e-08 - val_accuracy: 1.0000 - val_loss: 1.1325e-07
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 8.0373e-08
# Test accuracy: 1.0

# %%
print("Training images shape:", X_train.shape)
print("Validation images shape:", X_test.shape)
# Out:
# Training images shape: (320, 128, 128, 3)
# Validation images shape: (80, 128, 128, 3)

# %%
def load_and_predict(image_path):
    img = load_img(image_path, target_size=(128, 128))
    img_array = img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    prediction = model.predict(img_array)
    predicted_class = np.argmax(prediction, axis=1)
    return "Python" if predicted_class[0] == 1 else "C++"

test_images = glob.glob('/content/Test/*.png')

for image_path in test_images:
    predicted_label = load_and_predict(image_path)
    print('The predicted class for "' + image_path.split('/')[-1] + '" is: ' + predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# The predicted class for "cpp_code_image_8.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# The predicted class for "cpp_code_image_18.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# The predicted class for "python_code_image_9.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# The predicted class for "cpp_code_image_10.png" is: C++
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# The predicted class for "cpp_code_image_14.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# The predicted class for "python_code_image_21.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# The predicted class for "python_code_image_3.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# The predicted class for "python_code_image_1.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# The predicted class for "cpp_code_image_11.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# The predicted class for "cpp_code_image_22.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# The predicted class for "cpp_code_image_1.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_18.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_16.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "cpp_code_image_19.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_2.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# The predicted class for "python_code_image_25.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_8.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# The predicted class for "cpp_code_image_25.png" is: C++
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "cpp_code_image_9.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_24.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "cpp_code_image_21.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_22.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_5.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# The predicted class for "python_code_image_14.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_23.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# The predicted class for "python_code_image_7.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# The predicted class for "python_code_image_12.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# The predicted class for "cpp_code_image_6.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# The predicted class for "cpp_code_image_16.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_4.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# The predicted class for "cpp_code_image_2.png" is: C++
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_11.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "cpp_code_image_20.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# The predicted class for "cpp_code_image_4.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "cpp_code_image_13.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "cpp_code_image_23.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# The predicted class for "cpp_code_image_24.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# The predicted class for "cpp_code_image_15.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "cpp_code_image_17.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# The predicted class for "cpp_code_image_5.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_15.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_17.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# The predicted class for "cpp_code_image_7.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# The predicted class for "python_code_image_20.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# The predicted class for "cpp_code_image_12.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# The predicted class for "python_code_image_19.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_6.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# The predicted class for "python_code_image_13.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "cpp_code_image_3.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_10.png" is: Python

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.5141 - loss: 2.0138 - val_accuracy: 0.5500 - val_loss: 0.6766
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5147 - loss: 0.7112 - val_accuracy: 0.5500 - val_loss: 0.6442
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6120 - loss: 0.6519 - val_accuracy: 1.0000 - val_loss: 0.5985
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9991 - loss: 0.5743 - val_accuracy: 1.0000 - val_loss: 0.4540
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.4078 - val_accuracy: 1.0000 - val_loss: 0.2527
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.2240 - val_accuracy: 1.0000 - val_loss: 0.1528
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0908 - val_accuracy: 1.0000 - val_loss: 0.0366
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0240 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 9.0348e-04 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 8.5730e-04 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 8.0409e-04 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 6.8820e-04 - val_accuracy: 1.0000 - val_loss: 9.3305e-04
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 1.0000 - loss: 7.1709e-04 - val_accuracy: 1.0000 - val_loss: 8.6301e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 8.1655e-04
# Test accuracy: 1.0
# Training images shape: (320, 128, 128, 3)
# Validation images shape: (80, 128, 128, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# The predicted class for "cpp_code_image_8.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# The predicted class for "cpp_code_image_18.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# The predicted class for "python_code_image_9.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# The predicted class for "cpp_code_image_10.png" is: C++
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# The predicted class for "cpp_code_image_14.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# The predicted class for "python_code_image_21.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# The predicted class for "python_code_image_3.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# The predicted class for "python_code_image_1.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# The predicted class for "cpp_code_image_11.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# The predicted class for "cpp_code_image_22.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# The predicted class for "cpp_code_image_1.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# The predicted class for "python_code_image_18.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# The predicted class for "python_code_image_16.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# The predicted class for "cpp_code_image_19.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# The predicted class for "python_code_image_2.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_25.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# The predicted class for "python_code_image_8.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# The predicted class for "cpp_code_image_25.png" is: C++
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# The predicted class for "cpp_code_image_9.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# The predicted class for "python_code_image_24.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "cpp_code_image_21.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# The predicted class for "python_code_image_22.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_5.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_14.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_23.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_7.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# The predicted class for "python_code_image_12.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "cpp_code_image_6.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "cpp_code_image_16.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_4.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# The predicted class for "cpp_code_image_2.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_11.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "cpp_code_image_20.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# The predicted class for "cpp_code_image_4.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# The predicted class for "cpp_code_image_13.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# The predicted class for "cpp_code_image_23.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# The predicted class for "cpp_code_image_24.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# The predicted class for "cpp_code_image_15.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# The predicted class for "cpp_code_image_17.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "cpp_code_image_5.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_15.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# The predicted class for "python_code_image_17.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# The predicted class for "cpp_code_image_7.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# The predicted class for "python_code_image_20.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# The predicted class for "cpp_code_image_12.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# The predicted class for "python_code_image_19.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# The predicted class for "python_code_image_6.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# The predicted class for "python_code_image_13.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# The predicted class for "cpp_code_image_3.png" is: Python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# The predicted class for "python_code_image_10.png" is: Python
